# %%
import csv
from datetime import datetime
import requests
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
def get_url(position, location):
    """generate a url on positon and location"""
    template = 'https://www.indeed.com/jobs?q={}&l={}&sort=date='
    url = template.format(position, location)
    return url

# %%
gg = []
for j in range(0,15,10): # calling 15 entries
    
    position,location='data analyst','boston'
    
    r = requests.get('https://www.indeed.com/jobs?q={}&l={}&sort=date='.format(position,location)+str(j))
    print(r)

    salad = soup(r.text,'lxml')
    print(salad) 
    # spoiler alert: r = 200

    for ii in salad.find_all('div',{"class":"job_seen_beacon"}):
        j = ii.find('tbody') # calling the table body to go inside of
        a = j.find('tr') # going inside the table

        # job title
        for n in a.find_all('h2',{'class':'jobTitle jobTitle-color-purple jobTitle-newJob'}):
                job_title = n.find_all('span')[1].get_text() #"[1]" is a must or else you'll get the 'new' popsting
                print(job_title)
                gg.append(job_title)

        # company name -- in new nesting
                company_ = a.find('span',{'class':'companyName'}).get_text()
                print(company_)
                gg.append(company_)

        """ 
        # Salary -- if available
        if a.find('div',{'class':'heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly'}):
                salary_ = a.find('div',{'class':'metadata salary-snippet-container'})
                print(salary_)
                gg.append(salary_)
        else:
                print("N/A")
                gg.append(salary_)
        """
        
        # location -- remote/in office/etc
        if n.find('div',{'class':'companyLocation'}):
                location_ = a.find('pre')[1]
                print(location_)
                gg.append(location_)
        else:
                print("N/A")
                gg.append(location_)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <script id="polyfill-script-bundle">/* Polyfill service v3.110.1
#  * Disable minification (remove `.min` from URL path) for more info */
#
# ...

# %%
len(gg)
# Out:
# 58

# %%
gg
# Out:
# ['Data Analyst',
#  'Cataldo Ambulance',
#  None,
#  None,
#  None,
#  'Analyst, Data and Analysis',
#  'Digitas',
#  None,
#  None,
#  None,
#  'Data Analyst, Data Solutions',
#  'MasterCard',
#  None,
#  'Healthcare Data Analyst I-DACCI',
#  "Boston Children's Hospital",
#  None,
#  'Entry Level Business Analyst',
#  'Atlantictranstrading',
#  None,
#  None,
#  None,
#  'Data Analyst I',
#  'Massachusetts General Hospital(MGH)',
#  None,
#  None,
#  'Data Analyst',
#  'Tribute Home Care',
#  None,
#  None,
#  'Data Analyst',
#  'Cataldo Ambulance',
#  None,
#  'Analyst, Data and Analysis',
#  'Digitas',
#  None,
#  None,
#  None,
#  None,
#  'Data Analyst, Data Solutions',
#  'MasterCard',
#  None,
#  'Healthcare Data Analyst I-DACCI',
#  "Boston Children's Hospital",
#  None,
#  'Entry Level Business Analyst',
#  'Atlantictranstrading',
#  None,
#  None,
#  'Data Analyst I',
#  'Massachusetts General Hospital(MGH)',
#  None,
#  None,
#  None,
#  'Data Analyst',
# ...
